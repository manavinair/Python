# %%
#output
import pandas as pd
df = pd.read_csv('/Users/manavinair/Downloads/Sample Output - Sample Output.csv', index_col=False, delimiter = ',')
df
# Out:
#          event_timestamp  tag__id       tag__name  \
# 0    05/08/2021 21:30:39    35827  L_R1SDW_SPDREF
# 1    05/08/2021 21:30:49    35827  L_R1SDW_SPDREF
# 2    05/08/2021 21:30:59    35827  L_R1SDW_SPDREF
# 3    05/08/2021 21:31:09    35827  L_R1SDW_SPDREF
# 4    05/08/2021 21:31:19    35827  L_R1SDW_SPDREF
# ..                   ...      ...             ...
# 109  05/08/2021 21:48:49    83540  L_R1_CNT_PASS0
# 110  05/08/2021 21:48:59    83540  L_R1_CNT_PASS0
# 111  05/08/2021 21:49:09    83540  L_R1_CNT_PASS0
# 112  05/08/2021 21:49:19    83540  L_R1_CNT_PASS0
# 113  05/08/2021 21:49:29    83540  L_R1_CNT_PASS0
#
#                                   tag__desc  tag__value tag__unit
# 0    R1 Screw Down WS Speed Reference (mps)    0.000000       mps
# 1    R1 Screw Down WS Speed Reference (mps)   38.372524       mps
# 2    R1 Screw Down WS Speed Reference (mps)    0.000000       mps
# 3    R1 Screw Down WS Speed Reference (mps)   27.673532       mps
# ...

# %%
#input
import pandas as pd
df = pd.read_csv('/Users/manavinair/Downloads/Book1.csv', index_col=False, delimiter = ',')
df.rename(columns={'ItemId':'tag__id'}, inplace=True)
df.rename(columns={'ItemName':'tag__name'}, inplace=True)
df.rename(columns={'Comment':'tag__desc'}, inplace=True)
df=df.join(val)
#df.drop(['ComputerId'], axis=1, inplace=True)
#df['event_timestamp']=df['Date']+' '+df['Time']
df
# Out:
#     tag__id  ComputerId          tag__name  \
# 0     35827          10     L_R1SDW_SPDREF
# 1     35828          10     L_R1SDD_SPDREF
# 2     35829          10     L_R1SDL_SPDREF
# 3     35830          10     L_R1SDW_SPDFBK
# 4     35831          10     L_R1SDD_SPDFBK
# 5     35832          10     L_R1SDL_SPDFBK
# 6     35974          10   L_R1_ODG_AUX_B07
# 7     83528          10  RM1_RUNDOWN_ID_HS
# 8     83530          10      L_R1SD_WS_GAP
# 9     83531          10      L_R1SD_DS_GAP
# 10    83532          10   L_R1SD_WS_SPDREF
# 11    83533          10   L_R1SD_DS_SPDREF
# 12    83534          10    L_R1SDLS_SPDREF
# 13    83535          10   L_R1SD_WS_SPDFBK
# 14    83536          10   L_R1SD_DS_SPDFBK
# 15    83537          10    L_R1SDLS_SPDFBK
# 16    83538          10      L_R1SD_WS_CUR
# 17    83539          10      L_R1SD_DS_CUR
# 18    83540          10     L_R1_CNT_PASS0
#
#                                  tag__desc  Unit      event_timestamp
# ...

# %%
#input
import pandas as pd
df1 = pd.read_csv('/Users/manavinair/Downloads/Sample Input2.csv', index_col=False, delimiter = ',')
#df.rename(columns={'ItemId':'Tag__id'}, inplace=True)
#df.drop(['Date','Time'], axis=1, inplace=True)
val=df1['event_timestamp']=df1['Date'].astype(str)+' '+df1['Time']
val=df1['event_timestamp']
df1
# Out:
#              Date      Time  Milli Sec      event_timestamp
# 0      06-05-2022  21:58:33      140.0  06-05-2022 21:58:33
# 1      06-05-2022  21:58:33      145.0  06-05-2022 21:58:33
# 2      06-05-2022  21:58:33      150.0  06-05-2022 21:58:33
# 3      06-05-2022  21:58:33      155.0  06-05-2022 21:58:33
# 4      06-05-2022  21:58:33      160.0  06-05-2022 21:58:33
# ...           ...       ...        ...                  ...
# 12766         NaN       NaN        NaN                  NaN
# 12767         NaN       NaN        NaN                  NaN
# 12768         NaN       NaN        NaN                  NaN
# 12769         NaN       NaN        NaN                  NaN
# 12770         NaN       NaN        NaN                  NaN
#
# [12771 rows x 4 columns]

# %%
df['event_timestamp']
# Out:
# 0        06-05-2022 21:58:33
# 1        06-05-2022 21:58:33
# 2        06-05-2022 21:58:33
# 3        06-05-2022 21:58:33
# 4        06-05-2022 21:58:33
#                 ...
# 12766                    NaN
# 12767                    NaN
# 12768                    NaN
# 12769                    NaN
# 12770                    NaN
# Name: event_timestamp, Length: 12771, dtype: object
